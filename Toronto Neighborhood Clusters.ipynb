# %% [markdown]
# # Week 3 - Clustering in Toronto!

# %% [markdown]
# # Table of Contents
#
# <div style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item1">Get Neighborhoods Data from Wikipedia</a>
#
# 2. <a href="#item2">Get and Merge Geocode Data</a>
#
# 3. <a href="#item3">Analyze and Cluster the Data</a>
#
# </font>
# </div>

# %% [markdown]
# <a id='item1'></a>
# ## Part 1: Get the data from Wikipedia

# %%
import pandas as pd
import numpy as np
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geocoder
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
from IPython.display import display # make printed dataframes look nice
from IPython.display import HTML # make printed dataframes look nice
import matplotlib.cm as cm # Matplotlib and associated plotting modules
import matplotlib.colors as colors
from sklearn.cluster import KMeans # import k-means from clustering stage
import folium # map rendering library

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
dfs = pd.read_html(url)

# %%
# Table we want is the first one
df = dfs[0]

# Get rid of the rows without useful data (note that there aren't any rows that have a Borough but not a neighborhood)
df = df[df.Borough != "Not assigned"].reset_index(drop=True)

# Don't need to do any more processing because the data on Wikipedia is already in desired form
# Print dataframe's shape
print(df.shape)

# Show off the dataframe
display(df.head())
# Out:
# (103, 3)
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# ## Now, add the lat/long coordinates to the dataset

# %% [markdown]
# ### Ok after lots of banging my head against the wall I've decided to just download the darn data
# ### The following code represents my various attempts to get this to work. Skip all these blocks and start again with **"Part 2"**

# %% [raw]
# # Add columns for latitude, longitude
# df_man = df
# df_man['Address'] = df_man["Postal Code"].astype(str)+", Ontario, Canada"
# df_man = df_man.reindex(columns = df_man.columns.tolist() + ['Lat','Long'])
# df_man.head()
#
# from geopy.geocoders import Nominatim
# import time
# from tqdm import tqdm
# tqdm.pandas()
# geolocator = Nominatim(user_agent="toronto")
# for x in range(0,102):
#     address = df_man.iloc[x]['Address']
#     print(address)
#     location = geolocator.geocode(address)
#     if location is None:
#         latitude = 0
#         longitude = 0
#     else:
#         latitude = location.latitude
#         longitude = location.longitude
#     print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
#     time.sleep(3)
#
#
# from geopy.extra.rate_limiter import RateLimiter
# df_head = df_man.head(10)
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=5)
# df_head['Location'] = df_head['Address'].progress_apply(geocode)
#
# # filter the category for each row .apply(get_category_type, axis=1)
# df['Lat'], df['Long'] = df.apply(get_latlong, axis=1, result_type='expand').T.values
# df
#
# # function that gets the lat/long for each row
# def get_latlong(row):
#
#     from geopy.extra.rate_limiter import RateLimiter
#     # define the address
#     address = '{}, Toronto, Ontario'.format(row['Postal Code'])
#     print(address)
#
#     # initialize the geolocator
#     geolocator = Nominatim(user_agent="toronto_explorer")
#
#
#     # initialize variable to None
#     location = None
#     x = 0
#
#     # loop until you get the coordinates
#     while(location is None):
#         geocoder = RateLimiter(geolocator.geocode, min_delay_seconds=5)
#         x=x+1
#         location = geocoder(address)
#         print("Try number",x)
#         print(type(location))
#         if x >= 5: break
#
#     if location is None:
#         print("Failure!")
#         latitude = 0
#         longitude = 0
#     else:
#         print("Success!")
#         latitude = location.latitude
#         longitude = location.longitude
#
#     print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
#
#     return [latitude, longitude]
#
#
# df.to_csv("debug.csv")
#
# address = '{}, Toronto, Ontario'.format(df.loc[0,'Postal Code'])
#
# geolocator = Nominatim(user_agent="ny_explorer")
#
#
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print('The geographical coordinate of {} are {}, {}.'.format(address, latitude, longitude))

# %% [markdown]
# <a id='item2'></a>
# ## Part 2: Get and merge the geocoding data

# %%
# Load the data in a dataframe, merge with initial data
df_geo = pd.read_csv("Geospatial_Coordinates.csv")
df_merged = pd.merge(df, df_geo, on=['Postal Code'])
df_merged
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# 26          M1H       Scarborough
# 27          M2H        North York
# 28          M3H        North York
# 29          M4H         East York
# 30          M5H  Downtown Toronto
# 31          M6H      West Toronto
# 32          M1J       Scarborough
# 33          M2J        North York
# 34          M3J        North York
# 35          M4J         East York
# 36          M5J  Downtown Toronto
# 37          M6J      West Toronto
# 38          M1K       Scarborough
# 39          M2K        North York
# 40          M3K        North York
# 41          M4K      East Toronto
# 42          M5K  Downtown Toronto
# 43          M6K      West Toronto
# 44          M1L       Scarborough
# 45          M2L        North York
# 46          M3L        North York
# 47          M4L      East Toronto
# 48          M5L  Downtown Toronto
# 49          M6L        North York
# 50          M9L        North York
# 51          M1M       Scarborough
# 52          M2M        North York
# 53          M3M        North York
# 54          M4M      East Toronto
# 55          M5M        North York
# 56          M6M              York
# 57          M9M        North York
# 58          M1N       Scarborough
# 59          M2N        North York
# 60          M3N        North York
# 61          M4N   Central Toronto
# 62          M5N   Central Toronto
# 63          M6N              York
# 64          M9N              York
# 65          M1P       Scarborough
# 66          M2P        North York
# 67          M4P   Central Toronto
# 68          M5P   Central Toronto
# 69          M6P      West Toronto
# 70          M9P         Etobicoke
# 71          M1R       Scarborough
# 72          M2R        North York
# 73          M4R   Central Toronto
# 74          M5R   Central Toronto
# 75          M6R      West Toronto
# 76          M7R       Mississauga
# 77          M9R         Etobicoke
# 78          M1S       Scarborough
# 79          M4S   Central Toronto
# 80          M5S  Downtown Toronto
# 81          M6S      West Toronto
# 82          M1T       Scarborough
# 83          M4T   Central Toronto
# 84          M5T  Downtown Toronto
# 85          M1V       Scarborough
# 86          M4V   Central Toronto
# 87          M5V  Downtown Toronto
# 88          M8V         Etobicoke
# 89          M9V         Etobicoke
# 90          M1W       Scarborough
# 91          M4W  Downtown Toronto
# 92          M5W  Downtown Toronto
# 93          M8W         Etobicoke
# 94          M9W         Etobicoke
# 95          M1X       Scarborough
# 96          M4X  Downtown Toronto
# 97          M5X  Downtown Toronto
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 5              Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 6                                       Malvern, Rouge  43.806686 -79.194353
# 7                                            Don Mills  43.745906 -79.352188
# 8                      Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 9                             Garden District, Ryerson  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 12              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 13                                           Don Mills  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# 30                            Richmond, Adelaide, King  43.650571 -79.384568
# 31                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 32                                 Scarborough Village  43.744734 -79.239476
# 33                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 34                     Northwood Park, York University  43.767980 -79.487262
# 35       East Toronto, Broadview North (Old East York)  43.685347 -79.338106
# 36   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 38         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 39                                     Bayview Village  43.786947 -79.385975
# 40                                           Downsview  43.737473 -79.464763
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 43        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 44                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 45                            York Mills, Silver Hills  43.757490 -79.374714
# 46                                           Downsview  43.739015 -79.506944
# 47                      India Bazaar, The Beaches West  43.668999 -79.315572
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 49            North Park, Maple Leaf Park, Upwood Park  43.713756 -79.490074
# 50                                       Humber Summit  43.756303 -79.565963
# 51     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 52                             Willowdale, Newtonbrook  43.789053 -79.408493
# 53                                           Downsview  43.728496 -79.495697
# 54                                     Studio District  43.659526 -79.340923
# 55                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 56    Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 57                                    Humberlea, Emery  43.724766 -79.532242
# 58                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 59                         Willowdale, Willowdale East  43.770120 -79.408493
# 60                                           Downsview  43.761631 -79.520999
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 63                       Runnymede, The Junction North  43.673185 -79.487262
# 64                                              Weston  43.706876 -79.518188
# 65   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 66                                     York Mills West  43.752758 -79.400049
# 67                                    Davisville North  43.712751 -79.390197
# 68     Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 69                       High Park, The Junction South  43.661608 -79.464763
# 70                                           Westmount  43.696319 -79.532242
# 71                                   Wexford, Maryvale  43.750072 -79.295849
# 72                         Willowdale, Willowdale West  43.782736 -79.442259
# 73                   North Toronto West, Lawrence Park  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 85   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 86   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 87   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89   South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 90                       Steeles West, L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                                      Stn A PO Boxes  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                 Northwest, West Humber - Clairville  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999

# %% [markdown]
# <a id='item3'></a>
# ## Part 3: Analyze, Cluster and Label the Data Accordingly

# %%
# Begin by stripping out rows that don't contain the word "Toronto" in the Borough column
df_tor = df_merged[df_merged.Borough.str.contains("Toronto")].reset_index(drop=True)
df_tor
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M4E      East Toronto
# 5          M5E  Downtown Toronto
# 6          M5G  Downtown Toronto
# 7          M6G  Downtown Toronto
# 8          M5H  Downtown Toronto
# 9          M6H      West Toronto
# 10         M5J  Downtown Toronto
# 11         M6J      West Toronto
# 12         M4K      East Toronto
# 13         M5K  Downtown Toronto
# 14         M6K      West Toronto
# 15         M4L      East Toronto
# 16         M5L  Downtown Toronto
# 17         M4M      East Toronto
# 18         M4N   Central Toronto
# 19         M5N   Central Toronto
# 20         M4P   Central Toronto
# 21         M5P   Central Toronto
# 22         M6P      West Toronto
# 23         M4R   Central Toronto
# 24         M5R   Central Toronto
# 25         M6R      West Toronto
# 26         M4S   Central Toronto
# 27         M5S  Downtown Toronto
# 28         M6S      West Toronto
# 29         M4T   Central Toronto
# 30         M5T  Downtown Toronto
# 31         M4V   Central Toronto
# 32         M5V  Downtown Toronto
# 33         M4W  Downtown Toronto
# 34         M5W  Downtown Toronto
# 35         M4X  Downtown Toronto
# 36         M5X  Downtown Toronto
# 37         M4Y  Downtown Toronto
# 38         M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         The Beaches  43.676357 -79.293031
# 5                                         Berczy Park  43.644771 -79.373306
# 6                                  Central Bay Street  43.657952 -79.387383
# 7                                            Christie  43.669542 -79.422564
# 8                            Richmond, Adelaide, King  43.650571 -79.384568
# 9                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 10  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 11                           Little Portugal, Trinity  43.647927 -79.419750
# 12                       The Danforth West, Riverdale  43.679557 -79.352188
# 13           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 14       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 15                     India Bazaar, The Beaches West  43.668999 -79.315572
# 16                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 17                                    Studio District  43.659526 -79.340923
# 18                                      Lawrence Park  43.728020 -79.388790
# 19                                           Roselawn  43.711695 -79.416936
# 20                                   Davisville North  43.712751 -79.390197
# 21    Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 22                      High Park, The Junction South  43.661608 -79.464763
# 23                  North Toronto West, Lawrence Park  43.715383 -79.405678
# 24                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 25                             Parkdale, Roncesvalles  43.648960 -79.456325
# 26                                         Davisville  43.704324 -79.388790
# 27                     University of Toronto, Harbord  43.662696 -79.400049
# 28                                 Runnymede, Swansea  43.651571 -79.484450
# 29                        Moore Park, Summerhill East  43.689574 -79.383160
# 30          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 31  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 32  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 33                                           Rosedale  43.679563 -79.377529
# 34                                     Stn A PO Boxes  43.646435 -79.374846
# 35                        St. James Town, Cabbagetown  43.667967 -79.367675
# 36             First Canadian Place, Underground city  43.648429 -79.382280
# 37                               Church and Wellesley  43.665860 -79.383160
# 38  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %%
CLIENT_ID = 'R1H1D2GMPVIW3DV0ISLESHSVU0Q5TDMSLJHSX3GZQZM0RC1U' # your Foursquare ID
CLIENT_SECRET = '5YPLTXG0405EEDDYWZ03Z0S3OUFANDX1O5BOO1PU13R2QK0D' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# <br>
# <br>
#
# #### Begin by seeing the neighborhoods on a map

# %%
# Get coordinates for Toronto
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map using latitude and longitude values
map_tor = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, neighborhood in zip(df_tor['Latitude'], df_tor['Longitude'], df_tor['Neighborhood']):
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tor)  
    
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>
#
# #### Get first neighborhood's info

# %%
neighborhood_latitude = df_tor.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df_tor.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df_tor.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Regent Park, Harbourfront are 43.6542599, -79.3606359.

# %% [markdown]
# <br>
#
# #### Set the GET request URL, show the results

# %%
radius = 500
LIMIT = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, neighborhood_latitude, neighborhood_longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
venues1 = results['response']['venues']
venues1 = pd.json_normalize(venues1)
venues1
# Out:
#                           id  \
# 0   5bdc6c2bba57b4002c4c71a8
# 1   4bc70f5d14d7952126a066e9
# 2   53b8466a498e83df908c3f21
# 3   50760559e4b0e8c7babe2497
# 4   5e5d749285a0610007e60fe8
# 5   55e8cc7a498e795a53d81d36
# 6   4dc9d4d9d16495ca5add0803
# 7   4b0d4672f964a520854523e3
# 8   51853a73498e4d97a8b20831
# 9   54ea41ad498e9a11e9e13308
# 10  4e4fe1352271a1bdc3e4528a
# 11  58c8333104f4d7391587afd4
# 12  5e3618557bde930007d18b8d
# 13  4beb288d62c0c928dcc8e1d4
# 14  4de6a930d22d73244b8c71c4
# 15  4bfd8d52f61dc9b6d8309fde
# 16  4fa7ebe5a17c43f4427e572b
# 17  4e02deac18389833c594fe1d
# 18  4dd1ac05e4cd7f7178b89a3f
# 19  4beb1543415e20a10cdde5bb
# 20  5d8d192fd2219e0008624db1
# 21  4ca1de8b46978cfabc64bf7f
# 22  576864be498e42995f045b4e
# 23  4dd27b4d227159fef24ba1c2
# 24  5d266686f3c3c10023171ace
# 25  57b12ecf498e84b0379c079a
# 26  54248f4e498e455132a5cee7
# 27  5df44bb28a06ab0008f849b7
# 28  4ca5fcd576d3a09316dcfc6a
# 29  5102a429e4b0dbb0cee8a2cf
# 30  577bae44498ea36b56b4c29f
# 31  4e54574bb61c93816c084ddb
# 32  4b6f550bf964a520d7eb2ce3
# 33  4e8b7fa1cc2112f67517660a
# 34  4ef9db1e2c5b044502ebf777
# 35  5cd60624b9b37b002c47e8e3
# 36  5aad9b86fdb9a7176b2d50ac
# 37  4ae5b91ff964a520a6a121e3
# 38  4ad4c05ef964a5209bf620e3
# 39  5095afb6e4b0abc85696c8bf
# 40  4c45addf429a0f47b16b4a1e
# 41  593c465b67af3a7da066e73d
# 42  53110bb0498ede1db08bcf0d
# 43  4d94bab61646a35d03823da3
# 44  5252ab1311d257ce2b04c870
# 45  4bf5a3025e800f47cedfe5d4
# 46  4ba8d6fcf964a52030f339e3
# 47  4ce2ce4b7e2e236a27d9971b
# 48  4d067a2b26adb1f702f9dc70
# 49  4b30e149f964a52075fc24e3
# 50  4b1951c1f964a5202edb23e3
# 51  500d567be4b03c6eb45624a7
# 52  552ff7b5498e086325bc13ae
# 53  53ecb647498ef5787bb49169
# 54  58e92e150319b80a65d8476c
# 55  4b745564f964a520dbd52de3
# 56  4b5b51d0f964a5204df428e3
# 57  4cfd3c862d80a14396c255d8
# 58  4ee0043061aff91574f3c1d2
# 59  4d2003878629224b7fb20f87
# 60  51105013067da23696220482
# 61  4dc5b9e82271f27051353e8b
# 62  4bc8face68f976b085795c83
# 63  4d5304fe9d4937042817df39
# 64  4ce4188ec36ba35d1d7e73f6
# 65  4c12ae10b7b9c9282c3ea837
# 66  57f7f238498ea2b997bdc41a
# 67  554c0a58498e5cd466471285
# 68  4c507009f080a5935eff87e2
# 69  4d8b67f526a36ea8078c08ae
# 70  4b071a98f964a5204cf722e3
# 71  4d0370f528926ea8bf8e65c2
# 72  4e1cac0c45dd94fe4a555033
# 73  4cab7ad22776b60c07724c0d
# 74  550daea3498e35229ccaa319
# 75  4e5aa5fc52b1b78b81ad2674
# 76  4e52589caeb7560ca4ab67e9
# 77  4ce2d03af8a4a1439806f3bc
# 78  5592d4f1498e6ceb6183f0db
# 79  58d423c99398ab4da84d0a7a
# 80  5151c3fde4b02da132c9553e
# 81  550345a5498e3c6d808dac9b
# 82  521f43a911d28fe3900cc1b0
# 83  52d35257498e5d95b68841cc
# 84  4eea6e9f722edd1072f436b7
# 85  4de296c9ae60e7f3abf353cb
# 86  4f73a473e4b0c1f445d21c78
# 87  4c1284cda1010f4710014918
# 88  51c4d4c6498e92267ae5b2df
# 89  4b5f228ff964a5202da829e3
# 90  4eba8deacc21a9a7a1ebc7c3
# 91  55af01de498e560b44e89a82
# 92  4ca9f974f47ea143f5308421
# 93  4c61f84fedd320a1aafeab29
# 94  4fa6d7dee4b0d607ba1f089e
# 95  4db77f664b22f2ddb628e8b1
# 96  4ca4c68fb0ff8cfafeaec25e
# 97  4c2b905ad1a10f471325f864
# 98  4c2b9a28d1a10f47f634f864
# 99  4bd6ebaf6f6495213a8c71ec
#
#                                                 name  \
# 0                                     Oldtown Bodega
# 1                               Sackville Playground
# 2                                      Tandem Coffee
# 3                                Body Blitz Spa East
# 4             Terroni Sud Forno Produzione e Spaccio
# 5                     TTC Streetcar #503 Kingston Rd
# 6                                 Cam's Auto Service
# 7                         TTC Streetcar #504 King St
# 8                                     Rooster Coffee
# 9                                   Roselle Desserts
# 10                                      Roche Bobois
# 11                             Globe and Mail Centre
# 12                                         Gusto 501
# 13                             Fresh Home and Garden
# 14                                     Nella Cutlery
# 15                                         eco|stems
# 16                           Buster's Sea Cove Truck
# 17                     The Darkest Corner Of My Mind
# 18                                   360 Health Care
# 19                          Enoch Turner Schoolhouse
# 20                                     Bottē Gallery
# 21                               502 Queen Streetcar
# 22                       Orphan Black Police Station
# 23                                  Volvo of Toronto
# 24                      Hastings Barbershop Corktown
# 25                                              Face
# 26                                    Honda Downtown
# 27                       Maserati Alfa Romeo Service
# 28                      Sherwin-Williams Paint Store
# 29                                           Cambria
# 30                                         Starbucks
# 31                      Orphan's Greenspace Dog Park
# 32                    Little Trinity Anglican Church
# 33                                The Extension Room
# 34                                          studio b
# 35                                         Bar Reyna
# 36                                    Henrietta Lane
# 37                                Morning Glory Cafe
# 38                                       The Beaches
# 39                                     Trinity Lofts
# 40                                  Bay Cat Hospital
# 41                                     Ford Downtown
# 42                         AMI Artist Management Inc
# 43                        Ontario Early Years Centre
# 44                                               KBS
# 45                                    Central Import
# 46                          Massimo's Kitchen Studio
# 47                       Little Trinity Church Lands
# 48                  Thruway Muffler / Downtown Brake
# 49                                      Cosmic Karma
# 50                                    King Deli Cafe
# 51                                     Workplace One
# 52                                          STACKLAB
# 53                          Good Shepherd Ministries
# 54                             Libbys Custom Framing
# 55                                    Synecticsworld
# 56                                 downtown infiniti
# 57                                            Happin
# 58                                 Jane Roos Gallery
# 59                                      Ride Program
# 60  Thornton and Lucie Blackburn Archaeological Site
# 61                                       Jane's Walk
# 62                         Massimo Bruno Supper Club
# 63                             The Downtown Bodyshop
# 64                     Danish Connection/Gallery 402
# 65                                       Sports Time
# 66                                     The Dirty Inc
# 67                              The Corktown Kitchen
# 68                                Herrera's Catering
# 69                                Imaginis Marketing
# 70                      Assured - Downtown Collision
# 71                 Hyper Island Master Class Toronto
# 72                                         Happen NA
# 73                            Rookie Blue studio set
# 74                                       Gilead Café
# 75                                       Kenapalooza
# 76                                         PlateSpin
# 77                          Bright Street Playground
# 78                                       Union Sound
# 79    Advantage Car & Truck Rentals Downtown Toronto
# 80                             Power Park Off- leash
# 81                                      Linden Grove
# 82                          Downtown Hyundai Service
# 83                            Furnace Filters Canada
# 84                                   TTC Stop #04152
# 85                                    3 Gilead Place
# 86                                     Huayu Kitchen
# 87                                   Worldwide Quest
# 88                                      Dulux Paints
# 89                                Imperial Engravers
# 90                              Mazhari Auto Service
# 91                  Slip Rings Factory - Barlintimes
# 92                         Downtown Towing & Storage
# 93                                          MASS LBP
# 94                                            Zipcar
# 95           Riverside Evangelical Missionary Church
# 96                             Hamin Lee Photography
# 97                                           Aviso:#
# 98                                               AMI
# 99                        Inglenook Community School
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1593978421    False
# 1   [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1593978421    False
# 2   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1593978421    False
# 3   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...  v-1593978421    False
# 4   [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...  v-1593978421    False
# 5   [{'id': '4f2a23984b9023bd5841ed2c', 'name': 'M...  v-1593978421    False
# 6   [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 7   [{'id': '4f2a23984b9023bd5841ed2c', 'name': 'M...  v-1593978421    False
# 8   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1593978421    False
# 9   [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1593978421    False
# 10  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1593978421    False
# 11  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1593978421    False
# 12  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593978421    False
# 13  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1593978421    False
# 14                                                 []  v-1593978421    False
# 15  [{'id': '4bf58dd8d48988d11b951735', 'name': 'F...  v-1593978421    False
# 16  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1593978421    False
# 17  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...  v-1593978421    False
# 18  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...  v-1593978421    False
# 19  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...  v-1593978421    False
# 20  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1593978421    False
# 21  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1593978421    False
# 22  [{'id': '52e81612bcbc57f1066b79ee', 'name': 'S...  v-1593978421    False
# 23  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 24  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1593978421    False
# 25  [{'id': '4bf58dd8d48988d166941735', 'name': 'S...  v-1593978421    False
# 26  [{'id': '4eb1c1623b7b52c0e1adc2ec', 'name': 'A...  v-1593978421    False
# 27  [{'id': '4eb1c1623b7b52c0e1adc2ec', 'name': 'A...  v-1593978421    False
# 28  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...  v-1593978421    False
# 29  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1593978421    False
# 30  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1593978421    False
# 31  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...  v-1593978421    False
# 32  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1593978421    False
# 33  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1593978421    False
# 34  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1593978421    False
# 35  [{'id': '4bf58dd8d48988d1c0941735', 'name': 'M...  v-1593978421    False
# 36  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...  v-1593978421    False
# 37  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1593978421    False
# 38  [{'id': '4bf58dd8d48988d12d941735', 'name': 'M...  v-1593978421    False
# 39  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1593978421    False
# 40  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1593978421    False
# 41  [{'id': '4eb1c1623b7b52c0e1adc2ec', 'name': 'A...  v-1593978421    False
# 42  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1593978421    False
# 43  [{'id': '4f4532974b9074f6e4fb0104', 'name': 'D...  v-1593978421    False
# 44  [{'id': '52e81612bcbc57f1066b7a3d', 'name': 'A...  v-1593978421    False
# 45  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 46  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593978421    False
# 47  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1593978421    False
# 48  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1593978421    False
# 49  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1593978421    False
# 50  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1593978421    False
# 51  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...  v-1593978421    False
# 52  [{'id': '4bf58dd8d48988d1f4941735', 'name': 'D...  v-1593978421    False
# 53  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...  v-1593978421    False
# 54  [{'id': '4bf58dd8d48988d127951735', 'name': 'A...  v-1593978421    False
# 55                                                 []  v-1593978421    False
# 56  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 57                                                 []  v-1593978421    False
# 58  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1593978421    False
# 59                                                 []  v-1593978421    False
# 60  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...  v-1593978421    False
# 61  [{'id': '4bf58dd8d48988d162941735', 'name': 'O...  v-1593978421    False
# 62  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593978421    False
# 63  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 64  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1593978421    False
# 65  [{'id': '4bf58dd8d48988d1f2941735', 'name': 'S...  v-1593978421    False
# 66  [{'id': '4bf58dd8d48988d106951735', 'name': 'M...  v-1593978421    False
# 67  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...  v-1593978421    False
# 68                                                 []  v-1593978421    False
# 69                                                 []  v-1593978421    False
# 70  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 71                                                 []  v-1593978421    False
# 72                                                 []  v-1593978421    False
# 73                                                 []  v-1593978421    False
# 74  [{'id': '52e81612bcbc57f1066b79f1', 'name': 'B...  v-1593978421    False
# 75  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1593978421    False
# 76                                                 []  v-1593978421    False
# 77  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1593978421    False
# 78  [{'id': '52f2ab2ebcbc57f1066b8b37', 'name': 'R...  v-1593978421    False
# 79  [{'id': '4bf58dd8d48988d1ef941735', 'name': 'R...  v-1593978421    False
# 80  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...  v-1593978421    False
# 81  [{'id': '4bf58dd8d48988d11b951735', 'name': 'F...  v-1593978421    False
# 82  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 83  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...  v-1593978421    False
# 84  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1593978421    False
# 85  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1593978421    False
# 86  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1593978421    False
# 87  [{'id': '4bf58dd8d48988d1f6931735', 'name': 'G...  v-1593978421    False
# 88  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...  v-1593978421    False
# 89                                                 []  v-1593978421    False
# 90  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...  v-1593978421    False
# 91  [{'id': '5453de49498eade8af355881', 'name': 'B...  v-1593978421    False
# 92                                                 []  v-1593978421    False
# 93  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1593978421    False
# 94  [{'id': '4bf58dd8d48988d1ef941735', 'name': 'R...  v-1593978421    False
# 95  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...  v-1593978421    False
# 96  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1593978421    False
# 97  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1593978421    False
# 98  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1593978421    False
# 99  [{'id': '4bf58dd8d48988d13d941735', 'name': 'H...  v-1593978421    False
#
#     location.lat  location.lng  \
# 0      43.653966    -79.360752
# 1      43.654656    -79.359871
# 2      43.653559    -79.361809
# 3      43.654735    -79.359874
# 4      43.653903    -79.360018
# 5      43.648099    -79.382932
# 6      43.654195    -79.360545
# 7      43.646151    -79.396000
# 8      43.651900    -79.365609
# 9      43.653447    -79.362017
# 10     43.653460    -79.363372
# 11     43.651520    -79.364804
# 12     43.654810    -79.359595
# 13     43.653153    -79.360661
# 14     43.656426    -79.360749
# 15     43.653536    -79.362016
# 16     43.653647    -79.357878
# 17     43.654938    -79.360975
# 18     43.653361    -79.362061
# 19     43.652873    -79.361672
# 20     43.654110    -79.360976
# 21     43.660013    -79.344758
# 22     43.655757    -79.358012
# 23     43.652760    -79.360254
# 24     43.654175    -79.361020
# 25     43.654920    -79.359371
# 26     43.653115    -79.359170
# 27     43.653877    -79.358406
# 28     43.656372    -79.361293
# 29     43.653324    -79.363180
# 30     43.653844    -79.361283
# 31     43.654654    -79.362501
# 32     43.653092    -79.361937
# 33     43.653313    -79.359725
# 34     43.653966    -79.361662
# 35     43.653446    -79.362240
# 36     43.653911    -79.361395
# 37     43.653947    -79.361149
# 38     43.652107    -79.361172
# 39     43.652207    -79.360933
# 40     43.655393    -79.358540
# 41     43.655254    -79.358415
# 42     43.655380    -79.358710
# 43     43.655682    -79.361865
# 44     43.653398    -79.363096
# 45     43.655650    -79.358690
# 46     43.654770    -79.359698
# 47     43.653072    -79.362668
# 48     43.654242    -79.360853
# 49     43.652788    -79.360739
# 50     43.653906    -79.361147
# 51     43.653149    -79.362733
# 52     43.653334    -79.359838
# 53     43.655333    -79.362811
# 54     43.654126    -79.360682
# 55     43.653260    -79.360095
# 56     43.652403    -79.360325
# 57     43.653170    -79.360370
# 58     43.653962    -79.361090
# 59     43.655071    -79.362356
# 60     43.653699    -79.359215
# 61     43.654985    -79.361327
# 62     43.654763    -79.359511
# 63     43.653874    -79.361783
# 64     43.653990    -79.361090
# 65     43.652297    -79.360428
# 66     43.654114    -79.361250
# 67     43.653316    -79.362140
# 68     43.653647    -79.361942
# 69     43.655021    -79.361327
# 70     43.653252    -79.359548
# 71     43.653795    -79.358668
# 72     43.653207    -79.360446
# 73     43.652218    -79.359990
# 74     43.653699    -79.361156
# 75     43.653624    -79.361032
# 76     43.653047    -79.362921
# 77     43.656105    -79.359741
# 78     43.655830    -79.360952
# 79     43.656385    -79.360753
# 80     43.654763    -79.362408
# 81     43.653522    -79.362000
# 82     43.654259    -79.358493
# 83     43.653963    -79.359741
# 84     43.652894    -79.362850
# 85     43.653426    -79.360302
# 86     43.654148    -79.357826
# 87     43.654659    -79.359830
# 88     43.653851    -79.367689
# 89     43.655160    -79.363170
# 90     43.654172    -79.360468
# 91     43.652286    -79.361415
# 92     43.656076    -79.362594
# 93     43.653984    -79.361270
# 94     43.653726    -79.362885
# 95     43.655403    -79.359288
# 96     43.655394    -79.360309
# 97     43.654440    -79.359830
# 98     43.655407    -79.358705
# 99     43.653903    -79.359429
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 43.653966, 'lng':...                 34
# 1   [{'label': 'display', 'lat': 43.65465604258614...                 75
# 2   [{'label': 'display', 'lat': 43.65355870959944...                122
# 3   [{'label': 'display', 'lat': 43.65473505045365...                 80
# 4   [{'label': 'display', 'lat': 43.653903, 'lng':...                 63
# 5   [{'label': 'display', 'lat': 43.64809856353395...               1922
# 6   [{'label': 'display', 'lat': 43.65419500779484...                 10
# 7   [{'label': 'display', 'lat': 43.64615120880793...               2988
# 8   [{'label': 'display', 'lat': 43.65189965670432...                479
# 9   [{'label': 'display', 'lat': 43.65344672305267...                143
# 10  [{'label': 'display', 'lat': 43.65345988068375...                237
# 11  [{'label': 'display', 'lat': 43.65151977053267...                453
# 12  [{'label': 'display', 'lat': 43.65481, 'lng': ...                103
# 13  [{'label': 'display', 'lat': 43.65315257492276...                123
# 14  [{'label': 'display', 'lat': 43.65642649962338...                241
# 15  [{'label': 'display', 'lat': 43.65353579108864...                137
# 16  [{'label': 'display', 'lat': 43.65364665307943...                232
# 17  [{'label': 'display', 'lat': 43.654938, 'lng':...                 80
# 18  [{'label': 'display', 'lat': 43.653361, 'lng':...                152
# 19  [{'label': 'display', 'lat': 43.65287311275056...                175
# 20  [{'label': 'display', 'lat': 43.65411, 'lng': ...                 32
# 21  [{'label': 'display', 'lat': 43.66001333517798...               1430
# 22  [{'label': 'display', 'lat': 43.655757, 'lng':...                269
# 23  [{'label': 'display', 'lat': 43.65275970933268...                169
# 24  [{'label': 'display', 'lat': 43.654175, 'lng':...                 32
# 25  [{'label': 'display', 'lat': 43.65492, 'lng': ...                125
# 26  [{'label': 'display', 'lat': 43.65311455793185...                173
# 27  [{'label': 'display', 'lat': 43.653877, 'lng':...                184
# 28  [{'label': 'display', 'lat': 43.65637195011159...                240
# 29  [{'label': 'display', 'lat': 43.65332390802142...                229
# 30  [{'label': 'display', 'lat': 43.653844, 'lng':...                 69
# 31  [{'label': 'display', 'lat': 43.65465395413889...                156
# 32  [{'label': 'display', 'lat': 43.65309196622969...                166
# 33  [{'label': 'display', 'lat': 43.65331304337331...                128
# 34  [{'label': 'display', 'lat': 43.65396607597698...                 88
# 35  [{'label': 'display', 'lat': 43.653446, 'lng':...                157
# 36  [{'label': 'display', 'lat': 43.653911, 'lng':...                 72
# 37  [{'label': 'display', 'lat': 43.65394694263529...                 54
# 38  [{'label': 'display', 'lat': 43.65210687917351...                243
# 39  [{'label': 'display', 'lat': 43.65220660578397...                229
# 40  [{'label': 'display', 'lat': 43.655393, 'lng':...                210
# 41  [{'label': 'display', 'lat': 43.655254, 'lng':...                210
# 42  [{'label': 'display', 'lat': 43.65538, 'lng': ...                199
# 43  [{'label': 'display', 'lat': 43.655682, 'lng':...                186
# 44  [{'label': 'display', 'lat': 43.6533977758939,...                220
# 45  [{'label': 'display', 'lat': 43.65565, 'lng': ...                220
# 46  [{'label': 'display', 'lat': 43.65477003252322...                 94
# 47  [{'label': 'display', 'lat': 43.653072, 'lng':...                210
# 48  [{'label': 'display', 'lat': 43.65424167246142...                 17
# 49  [{'label': 'display', 'lat': 43.652788, 'lng':...                164
# 50  [{'label': 'display', 'lat': 43.65390613999999...                 56
# 51  [{'label': 'display', 'lat': 43.6531490637742,...                209
# 52  [{'label': 'display', 'lat': 43.65333396303207...                121
# 53  [{'label': 'display', 'lat': 43.65533281642919...                212
# 54  [{'label': 'display', 'lat': 43.654126, 'lng':...                 15
# 55  [{'label': 'display', 'lat': 43.65326, 'lng': ...                119
# 56  [{'label': 'display', 'lat': 43.65240276128636...                208
# 57  [{'label': 'display', 'lat': 43.65317, 'lng': ...                123
# 58  [{'label': 'display', 'lat': 43.65396193810649...                 49
# 59  [{'label': 'display', 'lat': 43.655071, 'lng':...                165
# 60  [{'label': 'display', 'lat': 43.65369880556223...                130
# 61  [{'label': 'display', 'lat': 43.654985, 'lng':...                 98
# 62  [{'label': 'display', 'lat': 43.65476308603427...                106
# 63  [{'label': 'display', 'lat': 43.653874, 'lng':...                101
# 64  [{'label': 'display', 'lat': 43.65398970001592...                 47
# 65  [{'label': 'display', 'lat': 43.652297, 'lng':...                219
# 66  [{'label': 'display', 'lat': 43.654114, 'lng':...                 52
# 67  [{'label': 'display', 'lat': 43.65331552573335...                160
# 68  [{'label': 'display', 'lat': 43.65364707666894...                125
# 69  [{'label': 'display', 'lat': 43.655021, 'lng':...                101
# 70  [{'label': 'display', 'lat': 43.653252, 'lng':...                142
# 71  [{'label': 'display', 'lat': 43.653795, 'lng':...                166
# 72  [{'label': 'display', 'lat': 43.65320650062366...                118
# 73  [{'label': 'display', 'lat': 43.65221836523209...                233
# 74  [{'label': 'display', 'lat': 43.65369882605437...                 75
# 75  [{'label': 'display', 'lat': 43.653624, 'lng':...                 77
# 76  [{'label': 'display', 'lat': 43.65304683761869...                228
# 77  [{'label': 'display', 'lat': 43.65610515821674...                217
# 78  [{'label': 'display', 'lat': 43.65583030087566...                176
# 79  [{'label': 'display', 'lat': 43.656385, 'lng':...                236
# 80  [{'label': 'display', 'lat': 43.654763, 'lng':...                153
# 81  [{'label': 'display', 'lat': 43.65352249145508...                137
# 82  [{'label': 'display', 'lat': 43.654259, 'lng':...                172
# 83  [{'label': 'display', 'lat': 43.65396273281939...                 79
# 84  [{'label': 'display', 'lat': 43.65289444556966...                234
# 85  [{'label': 'display', 'lat': 43.653426, 'lng':...                 96
# 86  [{'label': 'display', 'lat': 43.65414810180664...                226
# 87  [{'label': 'display', 'lat': 43.65465930209352...                 78
# 88  [{'label': 'display', 'lat': 43.653851, 'lng':...                569
# 89  [{'label': 'display', 'lat': 43.65516, 'lng': ...                227
# 90  [{'label': 'display', 'lat': 43.6541723866127,...                 16
# 91  [{'label': 'display', 'lat': 43.65228599875708...                228
# 92  [{'label': 'display', 'lat': 43.656076, 'lng':...                256
# 93  [{'label': 'display', 'lat': 43.65398407982623...                 59
# 94  [{'label': 'display', 'lat': 43.653726, 'lng':...                190
# 95  [{'label': 'display', 'lat': 43.655403, 'lng':...                167
# 96  [{'label': 'display', 'lat': 43.655394, 'lng':...                128
# 97  [{'label': 'display', 'lat': 43.65444, 'lng': ...                 67
# 98  [{'label': 'display', 'lat': 43.655407, 'lng':...                201
# 99  [{'label': 'display', 'lat': 43.65390281374826...                105
#
#    location.postalCode location.cc     location.city location.state  \
# 0              M5A 1L6          CA           Toronto             ON
# 1                  NaN          CA           Toronto             ON
# 2                  NaN          CA           Toronto             ON
# 3              M5A 1L9          CA           Toronto             ON
# 4              M5A 3E2          CA           Toronto             ON
# 5                  NaN          CA           Toronto             ON
# 6              M4M 2T7          CA           Toronto             ON
# 7                  NaN          CA           Toronto             ON
# 8              M5A 1L1          CA           Toronto             ON
# 9              M5A 1K9          CA           Toronto             ON
# 10             M5A 3Y7          CA           Toronto             ON
# 11             M5A 0N1          CA           Toronto             ON
# 12             M5A 1L9          CA           Toronto             ON
# 13                 NaN          CA           Toronto             ON
# 14              M5a1t5          CA           Toronto             ON
# 15             M5A 1K9          CA           Toronto             ON
# 16                 NaN          CA           Toronto             ON
# 17                 NaN          CA           Toronto             ON
# 18             M5A 1K9          CA           Toronto             ON
# 19             M5A 3C6          CA           Toronto             ON
# 20             M5A 1K9          CA           Toronto             ON
# 21                 NaN          CA           Toronto             ON
# 22                 NaN          CA           Toronto             ON
# 23                 NaN          CA           Toronto             ON
# 24             M5A 1L4          CA           Toronto             ON
# 25                 NaN          CA               NaN            NaN
# 26                 NaN          CA           Toronto             ON
# 27             M5A 0J3          CA           Toronto             ON
# 28             M5A 1T5          CA           Toronto             ON
# 29                 NaN          CA           Toronto             ON
# 30                 NaN          CA               NaN            NaN
# 31                 NaN          CA           Toronto             ON
# 32             M5A 1L3          CA           Toronto             ON
# 33                 NaN          CA           Toronto             ON
# 34             M5A 1K9          CA           Toronto             ON
# 35             M5A 1K9          CA           Toronto             ON
# 36             M5A 1K9          CA           Toronto             ON
# 37             M5A 1L6          CA           Toronto             ON
# 38             M4E 1C0          CA           Toronto             ON
# 39                 NaN          CA           Toronto             ON
# 40                 NaN          CA  Toronto Division             ON
# 41             M5A 1P7          CA           Toronto             ON
# 42                 NaN          CA               NaN            NaN
# 43             M5A 3E5          CA           Toronto             ON
# 44             M5A 1K8          CA           Toronto             ON
# 45             M5A 1L7          CA           Toronto             ON
# 46             M3H 6A7          CA           Toronto             ON
# 47                 NaN          CA           Toronto             ON
# 48             M5A 1L6          CA           Toronto             ON
# 49             M5A 3C7          CA           Toronto             ON
# 50                 NaN          CA           Toronto             ON
# 51             M5A 1K8          CA           Toronto             ON
# 52             M5A 1H5          CA           Toronto             ON
# 53                 NaN          CA           Toronto             ON
# 54             M5A 1L6          CA           Toronto             ON
# 55                 NaN          CA           Toronto             ON
# 56                 NaN          CA           Toronro             ON
# 57                 NaN          CA           Toronto             ON
# 58                 NaN          CA               NaN            NaN
# 59                 NaN          CA           Toronto             ON
# 60                 NaN          CA           Toronto             ON
# 61                 NaN          CA               NaN            NaN
# 62                 NaN          CA           Toronto             ON
# 63                 NaN          CA           Toronto             ON
# 64             M5A 1L6          CA           Toronto             ON
# 65                 NaN          CA           Toronto             ON
# 66             M5A 1K9          CA           Toronto             ON
# 67                 NaN          CA           Toronto             ON
# 68                 NaN          CA               NaN            NaN
# 69                 NaN          CA           Toronto             ON
# 70                 NaN          CA           Toronto             ON
# 71                 NaN          CA           Toronto             ON
# 72                 NaN          CA           Toronto             ON
# 73                 NaN          CA           Toronto             ON
# 74                 NaN          CA               NaN            NaN
# 75                 NaN          CA           Toronto             ON
# 76                 NaN          CA               NaN            NaN
# 77                 NaN          CA           Toronto             ON
# 78                 NaN          CA           Toronto             ON
# 79             M5A 1T5          CA           Toronto             ON
# 80                 NaN          CA               NaN            NaN
# 81                 NaN          CA               NaN            NaN
# 82                 NaN          CA               NaN            NaN
# 83             M3H 3M1          CA           Toronto             ON
# 84                 NaN          CA           Toronto             ON
# 85                 NaN          CA           Toronto             ON
# 86                 NaN          CA               NaN            NaN
# 87                 NaN          CA           Toronto             ON
# 88             M5A 1P6          CA           Toronto             ON
# 89                 NaN          CA               NaN            NaN
# 90             L6L 2X6          CA          Oakville             ON
# 91             M4X 1P8          CA           Toronto             ON
# 92                 NaN          CA               NaN            NaN
# 93             M5A 1K9          CA           Toronto             ON
# 94                 NaN          CA           Toronto             ON
# 95                 NaN          CA           Toronto             ON
# 96                 NaN          CA           Toronto             ON
# 97                 NaN          CA           Toronto             ON
# 98                 NaN          CA               NaN            NaN
# 99                 NaN          CA           Toronto             ON
#
#    location.country                          location.formattedAddress  \
# 0            Canada                       [Toronto ON M5A 1L6, Canada]
# 1            Canada                [420 king st E, Toronto ON, Canada]
# 2            Canada  [368 King St E (at Trinity St), Toronto ON, Ca...
# 3            Canada  [497 King Street East (btwn Sackville St and S...
# 4            Canada      [22 Sackville St, Toronto ON M5A 3E2, Canada]
# 5            Canada                               [Toronto ON, Canada]
# 6            Canada  [475 King Street East (Sackville Street), Toro...
# 7            Canada    [King St. (Moving Target!), Toronto ON, Canada]
# 8            Canada  [343 King St E (btwn Princess & Berkeley St), ...
# 9            Canada  [362 King St E (Trinity St), Toronto ON M5A 1K...
# 10           Canada  [101 Parliament Street, Toronto ON M5A 3Y7, Ca...
# 11           Canada  [351 King St E (Berkeley), Toronto ON M5A 0N1,...
# 12           Canada        [501 King St E, Toronto ON M5A 1L9, Canada]
# 13           Canada     [16 Eastern Ave (Trinity), Toronto ON, Canada]
# 14           Canada  [433 Queen Street East, Toronto ON M5a1t5, Can...
# 15           Canada  [364A King Street East (East of Parliament on ...
# 16           Canada                               [Toronto ON, Canada]
# 17           Canada                               [Toronto ON, Canada]
# 18           Canada       [360 King St. E, Toronto ON M5A 1K9, Canada]
# 19           Canada       [106 Trinity St, Toronto ON M5A 3C6, Canada]
# 20           Canada     [398 King st East, Toronto ON M5A 1K9, Canada]
# 21           Canada              [via Kingston Rd, Toronto ON, Canada]
# 22           Canada         [507 King Street East, Toronto ON, Canada]
# 23           Canada               [43 Eastern Ave, Toronto ON, Canada]
# 24           Canada                       [Toronto ON M5A 1L4, Canada]
# 25           Canada                                           [Canada]
# 26           Canada            [47 Eastern Avenue, Toronto ON, Canada]
# 27           Canada    [90 Eastern Avenue, Toronto ON M5A 0J3, Canada]
# 28           Canada  [423 Queen St E (Sackville St), Toronto ON M5A...
# 29           Canada                               [Toronto ON, Canada]
# 30           Canada                                           [Canada]
# 31           Canada  [51 Power St. (btwn Adelaide St. & Richmond Av...
# 32           Canada  [425 King St. E. (at Trinity St.), Toronto ON ...
# 33           Canada  [30 Eastern Ave (Sackville St.), Toronto ON, C...
# 34           Canada  [380 King Street East, Toronto ON M5A 1K9, Can...
# 35           Canada      [354 King St. E., Toronto ON M5A 1K9, Canada]
# 36           Canada  [394 King Street East, Toronto ON M5A 1K9, Can...
# 37           Canada  [457 King St. E (Gilead Place), Toronto ON M5A...
# 38           Canada  [Queen Street East (between Coxwell and Woodbi...
# 39           Canada            [90 Trinity Street, Toronto ON, Canada]
# 40           Canada    [525 King St East, Toronto Division ON, Canada]
# 41           Canada    [354 Richmond St E, Toronto ON M5A 1P7, Canada]
# 42           Canada                            [464 King St E, Canada]
# 43           Canada  [80 Sackville St, Rm 106 (Queen St E), Toronto...
# 44           Canada  [340 King St E (Parliament), Toronto ON M5A 1K...
# 45           Canada        [472 King St E, Toronto ON M5A 1L7, Canada]
# 46           Canada  [507 King St. E. (Sumach St), Toronto ON M3H 6...
# 47           Canada   [417 King St E (Parliament), Toronto ON, Canada]
# 48           Canada       [475 King St. E, Toronto ON M5A 1L6, Canada]
# 49           Canada  [95 Trinity Street (Eastern Ave), Toronto ON M...
# 50           Canada  [465 King Street E (just East of Parliament St...
# 51           Canada  [340 King Street East (Parliament), Toronto ON...
# 52           Canada  [28 Eastern Avenue (Parliament Street), Toront...
# 53           Canada                               [Toronto ON, Canada]
# 54           Canada      [465 King Street, Toronto ON M5A 1L6, Canada]
# 55           Canada  [2 Gilead Place (Eastern Ave. & Gilead Pl.), T...
# 56           Canada               [43 Eastern Ave, Toronro ON, Canada]
# 57           Canada  [16 eastern ave (Eastern and cherry), Toronto ...
# 58           Canada                                           [Canada]
# 59           Canada         [Richmond Street East, Toronto ON, Canada]
# 60           Canada  [54 Eastern Ave. (Sackville Street), Toronto O...
# 61           Canada                                           [Canada]
# 62           Canada              [507 King Street, Toronto ON, Canada]
# 63           Canada  [370 King Street East (Trinity Street), Toront...
# 64           Canada  [402 King St E (Wilkins ave), Toronto ON M5A 1...
# 65           Canada        [161 parliament street, Toronto ON, Canada]
# 66           Canada  [396 King Street East, Toronto ON M5A 1K9, Can...
# 67           Canada     [354 King St E (Power St), Toronto ON, Canada]
# 68           Canada                                           [Canada]
# 69           Canada         [495 King Street East, Toronto ON, Canada]
# 70           Canada               [32 Eastern Ave, Toronto ON, Canada]
# 71           Canada                               [Toronto ON, Canada]
# 72           Canada               [2 Gilead place, Toronto ON, Canada]
# 73           Canada            [373 Front st East, Toronto ON, Canada]
# 74           Canada                                           [Canada]
# 75           Canada                               [Toronto ON, Canada]
# 76           Canada                     [340 King Street East, Canada]
# 77           Canada      [50 Bright Street (King), Toronto ON, Canada]
# 78           Canada                               [Toronto ON, Canada]
# 79           Canada       [431 Queen St E, Toronto ON M5A 1T5, Canada]
# 80           Canada                                           [Canada]
# 81           Canada                                           [Canada]
# 82           Canada                                           [Canada]
# 83           Canada  [1A Dunsmore Gardens, Toronto ON M3H 3M1, Canada]
# 84           Canada  [King Street (Trinity Avenue), Toronto ON, Can...
# 85           Canada                               [Toronto ON, Canada]
# 86           Canada                                           [Canada]
# 87           Canada  [489 King St. E. (Sackville St.), Toronto ON, ...
# 88           Canada  [381 Richmond St E (Sackville), Toronto ON M5A...
# 89           Canada                     [80 Power St. (Queen), Canada]
# 90           Canada  [1476 Speers Rd #4, Oakville, ON L6L 2X6, Oakv...
# 91           Canada  [85 Parliament Street, Toronto ON M4X 1P8, Can...
# 92           Canada                                           [Canada]
# 93           Canada  [392A King St. E. (Trinity), Toronto ON M5A 1K...
# 94           Canada        [Adelaide (Parliament), Toronto ON, Canada]
# 95           Canada                [456 King St E, Toronto ON, Canada]
# 96           Canada                    [90 Sumach, Toronto ON, Canada]
# 97           Canada         [489 King Street East, Toronto ON, Canada]
# 98           Canada                                           [Canada]
# 99           Canada                 [19 Sackville, Toronto ON, Canada]
#
#                            location.address  \
# 0                                       NaN
# 1                             420 king st E
# 2                             368 King St E
# 3                      497 King Street East
# 4                           22 Sackville St
# 5                                       NaN
# 6                      475 King Street East
# 7                                  King St.
# 8                             343 King St E
# 9                             362 King St E
# 10                    101 Parliament Street
# 11                            351 King St E
# 12                            501 King St E
# 13                           16 Eastern Ave
# 14                    433 Queen Street East
# 15                    364A King Street East
# 16                                      NaN
# 17                                      NaN
# 18                           360 King St. E
# 19                           106 Trinity St
# 20                         398 King st East
# 21                          via Kingston Rd
# 22                     507 King Street East
# 23                           43 Eastern Ave
# 24                                      NaN
# 25                                      NaN
# 26                        47 Eastern Avenue
# 27                        90 Eastern Avenue
# 28                           423 Queen St E
# 29                                      NaN
# 30                                      NaN
# 31                             51 Power St.
# 32                          425 King St. E.
# 33                           30 Eastern Ave
# 34                     380 King Street East
# 35                          354 King St. E.
# 36                     394 King Street East
# 37                           457 King St. E
# 38                        Queen Street East
# 39                        90 Trinity Street
# 40                         525 King St East
# 41                        354 Richmond St E
# 42                            464 King St E
# 43                  80 Sackville St, Rm 106
# 44                            340 King St E
# 45                            472 King St E
# 46                          507 King St. E.
# 47                            417 King St E
# 48                           475 King St. E
# 49                        95 Trinity Street
# 50                        465 King Street E
# 51                     340 King Street East
# 52                        28 Eastern Avenue
# 53                                      NaN
# 54                          465 King Street
# 55                           2 Gilead Place
# 56                           43 Eastern Ave
# 57                           16 eastern ave
# 58                                      NaN
# 59                     Richmond Street East
# 60                          54 Eastern Ave.
# 61                                      NaN
# 62                          507 King Street
# 63                     370 King Street East
# 64                            402 King St E
# 65                    161 parliament street
# 66                     396 King Street East
# 67                            354 King St E
# 68                                      NaN
# 69                     495 King Street East
# 70                           32 Eastern Ave
# 71                                      NaN
# 72                           2 Gilead place
# 73                        373 Front st East
# 74                                      NaN
# 75                                      NaN
# 76                     340 King Street East
# 77                         50 Bright Street
# 78                                      NaN
# 79                           431 Queen St E
# 80                                      NaN
# 81                                      NaN
# 82                                      NaN
# 83                      1A Dunsmore Gardens
# 84                              King Street
# 85                                      NaN
# 86                                      NaN
# 87                          489 King St. E.
# 88                        381 Richmond St E
# 89                             80 Power St.
# 90  1476 Speers Rd #4, Oakville, ON L6L 2X6
# 91                     85 Parliament Street
# 92                                      NaN
# 93                         392A King St. E.
# 94                                 Adelaide
# 95                            456 King St E
# 96                                90 Sumach
# 97                     489 King Street East
# 98                                      NaN
# 99                             19 Sackville
#
#                    location.crossStreet venuePage.id
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2                         at Trinity St          NaN
# 3       btwn Sackville St and Sumach St          NaN
# 4                                   NaN          NaN
# 5                                   NaN          NaN
# 6                      Sackville Street          NaN
# 7                        Moving Target!          NaN
# 8           btwn Princess & Berkeley St          NaN
# 9                            Trinity St          NaN
# 10                                  NaN          NaN
# 11                             Berkeley          NaN
# 12                                  NaN          NaN
# 13                              Trinity          NaN
# 14                                  NaN          NaN
# 15           East of Parliament on King     57556934
# 16                                  NaN          NaN
# 17                                  NaN          NaN
# 18                                  NaN          NaN
# 19                                  NaN          NaN
# 20                                  NaN          NaN
# 21                                  NaN          NaN
# 22                                  NaN          NaN
# 23                                  NaN          NaN
# 24                                  NaN          NaN
# 25                                  NaN          NaN
# 26                                  NaN          NaN
# 27                                  NaN          NaN
# 28                         Sackville St          NaN
# 29                                  NaN          NaN
# 30                                  NaN          NaN
# 31    btwn Adelaide St. & Richmond Ave.          NaN
# 32                       at Trinity St.          NaN
# 33                        Sackville St.          NaN
# 34                                  NaN          NaN
# 35                                  NaN          NaN
# 36                                  NaN          NaN
# 37                         Gilead Place     39686393
# 38  between Coxwell and Woodbine Avenue          NaN
# 39                                  NaN          NaN
# 40                                  NaN          NaN
# 41                                  NaN          NaN
# 42                                  NaN          NaN
# 43                           Queen St E          NaN
# 44                           Parliament          NaN
# 45                                  NaN          NaN
# 46                            Sumach St          NaN
# 47                           Parliament          NaN
# 48                                  NaN          NaN
# 49                          Eastern Ave          NaN
# 50           just East of Parliament St          NaN
# 51                           Parliament          NaN
# 52                    Parliament Street          NaN
# 53                                  NaN          NaN
# 54                                  NaN          NaN
# 55            Eastern Ave. & Gilead Pl.          NaN
# 56                                  NaN          NaN
# 57                   Eastern and cherry          NaN
# 58                                  NaN          NaN
# 59                                  NaN          NaN
# 60                     Sackville Street          NaN
# 61                                  NaN          NaN
# 62                                  NaN          NaN
# 63                       Trinity Street          NaN
# 64                          Wilkins ave          NaN
# 65                                  NaN          NaN
# 66                                  NaN          NaN
# 67                             Power St          NaN
# 68                                  NaN          NaN
# 69                                  NaN          NaN
# 70                                  NaN          NaN
# 71                                  NaN          NaN
# 72                                  NaN          NaN
# 73                                  NaN          NaN
# 74                                  NaN          NaN
# 75                                  NaN          NaN
# 76                                  NaN          NaN
# 77                                 King          NaN
# 78                                  NaN          NaN
# 79                                  NaN    405580991
# 80                                  NaN          NaN
# 81                                  NaN          NaN
# 82                                  NaN          NaN
# 83                                  NaN          NaN
# 84                       Trinity Avenue          NaN
# 85                                  NaN          NaN
# 86                                  NaN          NaN
# 87                        Sackville St.          NaN
# 88                            Sackville          NaN
# 89                                Queen          NaN
# 90                                  NaN          NaN
# 91                                  NaN          NaN
# 92                                  NaN          NaN
# 93                              Trinity     39686391
# 94                           Parliament          NaN
# 95                                  NaN          NaN
# 96                                  NaN          NaN
# 97                                  NaN          NaN
# 98                                  NaN          NaN
# 99                                  NaN          NaN

# %% [markdown]
# <br>
#
# #### Define function to get the category from the JSON

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        #print(row['categories'][0]['name'])
        return row['categories'][0]['name']
    except:
        #print("Uncategorized")
        return "Uncategorized"

# %% [markdown]
# <br>
#
# #### Organize the data

# %%
# filter columns
filtered_columns = ['name', 'categories', 'location.lat', 'location.lng']
venues = venues1.loc[:, filtered_columns]

# filter the category for each row
venues['categories'] = venues.apply(get_category_type, axis=1)

# clean columns
#venues.columns = [col.split(".")[-1] for col in venues.columns]
#venues = venues.dropna(how='any',axis=0)
#venues.reset_index(drop=True, inplace=True)

venues.head()
# Out:
#                                      name    categories  location.lat  \
# 0                          Oldtown Bodega          Café     43.653966
# 1                    Sackville Playground          Park     43.654656
# 2                           Tandem Coffee   Coffee Shop     43.653559
# 3                     Body Blitz Spa East           Spa     43.654735
# 4  Terroni Sud Forno Produzione e Spaccio  Gourmet Shop     43.653903
#
#    location.lng
# 0    -79.360752
# 1    -79.359871
# 2    -79.361809
# 3    -79.359874
# 4    -79.360018

# %% [markdown]
# <br>
#
# #### Define function to get nearby venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()
        #with open('debug.json', 'w') as outfile:
        #    json.dump(results, outfile)
        venues1 = results['response']['venues']
        venues1 = pd.json_normalize(venues1)
        filtered_columns = ['name', 'categories', 'location.lat', 'location.lng']
        venues = venues1.loc[:, filtered_columns]
        venues = venues.rename(columns={'location.lat': 'latitude', 'location.lng': 'longitude'})
        venues['categories'] = venues.apply(get_category_type, axis=1)
        
        for row in venues.itertuples():
            venues_list.append([(name, 
                               lat, 
                               lng, 
                               row.name, 
                               row.latitude, 
                               row.longitude, 
                               row.categories
                              )])
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# <br>
#
# #### Run function on our neighborhoods and see the results

# %%
tor_venues = []
tor_venues = getNearbyVenues(names=df_tor['Neighborhood'],
                                   latitudes=df_tor['Latitude'],
                                   longitudes=df_tor['Longitude']
                                  )

# %%
tor_venues = tor_venues[tor_venues["Venue Category"] != "Uncategorized"].reset_index(drop=True)
print(tor_venues.shape)
tor_venues.head(20)
# Out:
# (3292, 7)
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   Regent Park, Harbourfront               43.65426              -79.360636
# 1   Regent Park, Harbourfront               43.65426              -79.360636
# 2   Regent Park, Harbourfront               43.65426              -79.360636
# 3   Regent Park, Harbourfront               43.65426              -79.360636
# 4   Regent Park, Harbourfront               43.65426              -79.360636
# 5   Regent Park, Harbourfront               43.65426              -79.360636
# 6   Regent Park, Harbourfront               43.65426              -79.360636
# 7   Regent Park, Harbourfront               43.65426              -79.360636
# 8   Regent Park, Harbourfront               43.65426              -79.360636
# 9   Regent Park, Harbourfront               43.65426              -79.360636
# 10  Regent Park, Harbourfront               43.65426              -79.360636
# 11  Regent Park, Harbourfront               43.65426              -79.360636
# 12  Regent Park, Harbourfront               43.65426              -79.360636
# 13  Regent Park, Harbourfront               43.65426              -79.360636
# 14  Regent Park, Harbourfront               43.65426              -79.360636
# 15  Regent Park, Harbourfront               43.65426              -79.360636
# 16  Regent Park, Harbourfront               43.65426              -79.360636
# 17  Regent Park, Harbourfront               43.65426              -79.360636
# 18  Regent Park, Harbourfront               43.65426              -79.360636
# 19  Regent Park, Harbourfront               43.65426              -79.360636
#
#                                      Venue  Venue Latitude  Venue Longitude  \
# 0                           Oldtown Bodega       43.653966       -79.360752
# 1                     Sackville Playground       43.654656       -79.359871
# 2                            Tandem Coffee       43.653559       -79.361809
# 3                      Body Blitz Spa East       43.654735       -79.359874
# 4   Terroni Sud Forno Produzione e Spaccio       43.653903       -79.360018
# 5           TTC Streetcar #503 Kingston Rd       43.648099       -79.382932
# 6                       Cam's Auto Service       43.654195       -79.360545
# 7               TTC Streetcar #504 King St       43.646151       -79.396000
# 8                           Rooster Coffee       43.651900       -79.365609
# 9                         Roselle Desserts       43.653447       -79.362017
# 10                            Roche Bobois       43.653460       -79.363372
# 11                   Globe and Mail Centre       43.651520       -79.364804
# 12                               Gusto 501       43.654810       -79.359595
# 13                   Fresh Home and Garden       43.653153       -79.360661
# 14                               eco|stems       43.653536       -79.362016
# 15                 Buster's Sea Cove Truck       43.653647       -79.357878
# 16           The Darkest Corner Of My Mind       43.654938       -79.360975
# 17                         360 Health Care       43.653361       -79.362061
# 18                Enoch Turner Schoolhouse       43.652873       -79.361672
# 19                           Bottē Gallery       43.654110       -79.360976
#
#             Venue Category
# 0                     Café
# 1                     Park
# 2              Coffee Shop
# 3                      Spa
# 4             Gourmet Shop
# 5            Moving Target
# 6          Automotive Shop
# 7            Moving Target
# 8              Coffee Shop
# 9                   Bakery
# 10  Furniture / Home Store
# 11                Building
# 12      Italian Restaurant
# 13  Furniture / Home Store
# 14             Flower Shop
# 15              Food Truck
# 16                 Library
# 17          Medical Center
# 18          History Museum
# 19             Art Gallery

# %% [markdown]
# <br>
#
# #### Get some information about the dataset

# %%
display(tor_venues.groupby('Neighborhood').count())
print('There are {} uniques categories.'.format(len(tor_venues['Venue Category'].unique())))
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            84
# Brockton, Parkdale Village, Exhibition Place                           92
# Business reply mail Processing Centre, South Ce...                     79
# CN Tower, King and Spadina, Railway Lands, Harb...                     62
# Central Bay Street                                                     96
# Christie                                                               94
# Church and Wellesley                                                   90
# Commerce Court, Victoria Hotel                                         94
# Davisville                                                             81
# Davisville North                                                       71
# Dufferin, Dovercourt Village                                           92
# First Canadian Place, Underground city                                 97
# Forest Hill North & West, Forest Hill Road Park                        76
# Garden District, Ryerson                                               92
# Harbourfront East, Union Station, Toronto Islands                      65
# High Park, The Junction South                                          44
# India Bazaar, The Beaches West                                         87
# Kensington Market, Chinatown, Grange Park                              93
# Lawrence Park                                                          81
# Little Portugal, Trinity                                               92
# Moore Park, Summerhill East                                            85
# North Toronto West, Lawrence Park                                      84
# Parkdale, Roncesvalles                                                 88
# Queen's Park, Ontario Provincial Government                            72
# Regent Park, Harbourfront                                              88
# Richmond, Adelaide, King                                               96
# Rosedale                                                               87
# Roselawn                                                               72
# Runnymede, Swansea                                                     93
# St. James Town                                                         92
# St. James Town, Cabbagetown                                            92
# Stn A PO Boxes                                                         55
# Studio District                                                        87
# Summerhill West, Rathnelly, South Hill, Forest ...                     86
# The Annex, North Midtown, Yorkville                                    84
# The Beaches                                                            87
# The Danforth West, Riverdale                                           94
# Toronto Dominion Centre, Design Exchange                               92
# University of Toronto, Harbord                                         96
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             84
# Brockton, Parkdale Village, Exhibition Place                            92
# Business reply mail Processing Centre, South Ce...                      79
# CN Tower, King and Spadina, Railway Lands, Harb...                      62
# Central Bay Street                                                      96
# Christie                                                                94
# Church and Wellesley                                                    90
# Commerce Court, Victoria Hotel                                          94
# Davisville                                                              81
# Davisville North                                                        71
# Dufferin, Dovercourt Village                                            92
# First Canadian Place, Underground city                                  97
# Forest Hill North & West, Forest Hill Road Park                         76
# Garden District, Ryerson                                                92
# Harbourfront East, Union Station, Toronto Islands                       65
# High Park, The Junction South                                           44
# India Bazaar, The Beaches West                                          87
# Kensington Market, Chinatown, Grange Park                               93
# Lawrence Park                                                           81
# Little Portugal, Trinity                                                92
# Moore Park, Summerhill East                                             85
# North Toronto West, Lawrence Park                                       84
# Parkdale, Roncesvalles                                                  88
# Queen's Park, Ontario Provincial Government                             72
# Regent Park, Harbourfront                                               88
# Richmond, Adelaide, King                                                96
# Rosedale                                                                87
# Roselawn                                                                72
# Runnymede, Swansea                                                      93
# St. James Town                                                          92
# St. James Town, Cabbagetown                                             92
# Stn A PO Boxes                                                          55
# Studio District                                                         87
# Summerhill West, Rathnelly, South Hill, Forest ...                      86
# The Annex, North Midtown, Yorkville                                     84
# The Beaches                                                             87
# The Danforth West, Riverdale                                            94
# Toronto Dominion Centre, Design Exchange                                92
# University of Toronto, Harbord                                          96
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            84              84
# Brockton, Parkdale Village, Exhibition Place           92              92
# Business reply mail Processing Centre, South Ce...     79              79
# CN Tower, King and Spadina, Railway Lands, Harb...     62              62
# Central Bay Street                                     96              96
# Christie                                               94              94
# Church and Wellesley                                   90              90
# Commerce Court, Victoria Hotel                         94              94
# Davisville                                             81              81
# Davisville North                                       71              71
# Dufferin, Dovercourt Village                           92              92
# First Canadian Place, Underground city                 97              97
# Forest Hill North & West, Forest Hill Road Park        76              76
# Garden District, Ryerson                               92              92
# Harbourfront East, Union Station, Toronto Islands      65              65
# High Park, The Junction South                          44              44
# India Bazaar, The Beaches West                         87              87
# Kensington Market, Chinatown, Grange Park              93              93
# Lawrence Park                                          81              81
# Little Portugal, Trinity                               92              92
# Moore Park, Summerhill East                            85              85
# North Toronto West, Lawrence Park                      84              84
# Parkdale, Roncesvalles                                 88              88
# Queen's Park, Ontario Provincial Government            72              72
# Regent Park, Harbourfront                              88              88
# Richmond, Adelaide, King                               96              96
# Rosedale                                               87              87
# Roselawn                                               72              72
# Runnymede, Swansea                                     93              93
# St. James Town                                         92              92
# St. James Town, Cabbagetown                            92              92
# Stn A PO Boxes                                         55              55
# Studio District                                        87              87
# Summerhill West, Rathnelly, South Hill, Forest ...     86              86
# The Annex, North Midtown, Yorkville                    84              84
# The Beaches                                            87              87
# The Danforth West, Riverdale                           94              94
# Toronto Dominion Centre, Design Exchange               92              92
# University of Toronto, Harbord                         96              96
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      84
# Brockton, Parkdale Village, Exhibition Place                     92
# Business reply mail Processing Centre, South Ce...               79
# CN Tower, King and Spadina, Railway Lands, Harb...               62
# Central Bay Street                                               96
# Christie                                                         94
# Church and Wellesley                                             90
# Commerce Court, Victoria Hotel                                   94
# Davisville                                                       81
# Davisville North                                                 71
# Dufferin, Dovercourt Village                                     92
# First Canadian Place, Underground city                           97
# Forest Hill North & West, Forest Hill Road Park                  76
# Garden District, Ryerson                                         92
# Harbourfront East, Union Station, Toronto Islands                65
# High Park, The Junction South                                    44
# India Bazaar, The Beaches West                                   87
# Kensington Market, Chinatown, Grange Park                        93
# Lawrence Park                                                    81
# Little Portugal, Trinity                                         92
# Moore Park, Summerhill East                                      85
# North Toronto West, Lawrence Park                                84
# Parkdale, Roncesvalles                                           88
# Queen's Park, Ontario Provincial Government                      72
# Regent Park, Harbourfront                                        88
# Richmond, Adelaide, King                                         96
# Rosedale                                                         87
# Roselawn                                                         72
# Runnymede, Swansea                                               93
# St. James Town                                                   92
# St. James Town, Cabbagetown                                      92
# Stn A PO Boxes                                                   55
# Studio District                                                  87
# Summerhill West, Rathnelly, South Hill, Forest ...               86
# The Annex, North Midtown, Yorkville                              84
# The Beaches                                                      87
# The Danforth West, Riverdale                                     94
# Toronto Dominion Centre, Design Exchange                         92
# University of Toronto, Harbord                                   96
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     84
# Brockton, Parkdale Village, Exhibition Place                    92
# Business reply mail Processing Centre, South Ce...              79
# CN Tower, King and Spadina, Railway Lands, Harb...              62
# Central Bay Street                                              96
# Christie                                                        94
# Church and Wellesley                                            90
# Commerce Court, Victoria Hotel                                  94
# Davisville                                                      81
# Davisville North                                                71
# Dufferin, Dovercourt Village                                    92
# First Canadian Place, Underground city                          97
# Forest Hill North & West, Forest Hill Road Park                 76
# Garden District, Ryerson                                        92
# Harbourfront East, Union Station, Toronto Islands               65
# High Park, The Junction South                                   44
# India Bazaar, The Beaches West                                  87
# Kensington Market, Chinatown, Grange Park                       93
# Lawrence Park                                                   81
# Little Portugal, Trinity                                        92
# Moore Park, Summerhill East                                     85
# North Toronto West, Lawrence Park                               84
# Parkdale, Roncesvalles                                          88
# Queen's Park, Ontario Provincial Government                     72
# Regent Park, Harbourfront                                       88
# Richmond, Adelaide, King                                        96
# Rosedale                                                        87
# Roselawn                                                        72
# Runnymede, Swansea                                              93
# St. James Town                                                  92
# St. James Town, Cabbagetown                                     92
# Stn A PO Boxes                                                  55
# Studio District                                                 87
# Summerhill West, Rathnelly, South Hill, Forest ...              86
# The Annex, North Midtown, Yorkville                             84
# The Beaches                                                     87
# The Danforth West, Riverdale                                    94
# Toronto Dominion Centre, Design Exchange                        92
# University of Toronto, Harbord                                  96
# There are 409 uniques categories.

# %% [markdown]
# <br>
#
# #### Use data for neighborhoods analysis

# %%
# one hot encoding
tor_onehot = pd.get_dummies(tor_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
tor_onehot['Neighborhood'] = tor_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [tor_onehot.columns[-1]] + list(tor_onehot.columns[:-1])
tor_onehot = tor_onehot[fixed_columns]
tor_grouped = tor_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# <br>
#
# #### Check out the top five venues for each neighborhood

# %%
num_top_venues = 5

for hood in tor_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = tor_grouped[tor_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                                       venue  freq
# 0                                    Office  0.08
# 1                                  Building  0.07
# 2                                   Parking  0.04
# 3  Residential Building (Apartment / Condo)  0.04
# 4                                Food Truck  0.02
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                                       venue  freq
# 0                                    Office  0.26
# 1  Residential Building (Apartment / Condo)  0.17
# 2                              Tech Startup  0.07
# 3                        Advertising Agency  0.03
# 4                                  Building  0.03
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                 venue  freq
# 0            Building  0.05
# 1  Light Rail Station  0.04
# 2              Office  0.04
# 3      Medical Center  0.03
# 4        Antique Shop  0.03
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0      Airport Gate  0.19
# 1   Airport Service  0.11
# 2     Moving Target  0.08
# 3  Airport Terminal  0.05
# 4     Boat or Ferry  0.03
#
#
# ----Central Bay Street----
#             venue  freq
# 0        Hospital  0.21
# 1   Hospital Ward  0.06
# 2     Coffee Shop  0.05
# 3  Medical Center  0.04
# 4        Pharmacy  0.03
#
#
# ----Christie----
#                     venue  freq
# 0                  Office  0.07
# 1                    Café  0.06
# 2         Automotive Shop  0.03
# 3  Furniture / Home Store  0.03
# 4         Laundry Service  0.03
#
#
# ----Church and Wellesley----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.10
# 1                                       Spa  0.06
# 2                     General Entertainment  0.03
# 3                      Gym / Fitness Center  0.03
# 4                                       Gym  0.03
#
#
# ----Commerce Court, Victoria Hotel----
#                         venue  freq
# 0                      Office  0.18
# 1                 Coffee Shop  0.04
# 2  Financial or Legal Service  0.04
# 3                        Bank  0.03
# 4                  Food Court  0.03
#
#
# ----Davisville----
#                 venue  freq
# 0         Coffee Shop  0.06
# 1                Café  0.06
# 2  Italian Restaurant  0.05
# 3  Salon / Barbershop  0.05
# 4         Flower Shop  0.04
#
#
# ----Davisville North----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.30
# 1                                    Office  0.06
# 2                                   Dog Run  0.04
# 3                                       Gym  0.03
# 4                            Scenic Lookout  0.03
#
#
# ----Dufferin, Dovercourt Village----
#                     venue  freq
# 0         Automotive Shop  0.07
# 1                    Park  0.05
# 2                  Church  0.04
# 3  Furniture / Home Store  0.03
# 4   Portuguese Restaurant  0.03
#
#
# ----First Canadian Place, Underground city----
#             venue  freq
# 0          Bakery  0.04
# 1     Coffee Shop  0.04
# 2  Cosmetics Shop  0.03
# 3  Clothing Store  0.03
# 4          Office  0.03
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.05
# 1                                    Office  0.05
# 2                              Tech Startup  0.04
# 3                                      Park  0.04
# 4                      Gym / Fitness Center  0.04
#
#
# ----Garden District, Ryerson----
#                              venue  freq
# 0                      College Lab  0.10
# 1                       University  0.05
# 2  College Communications Building  0.04
# 3     General College & University  0.04
# 4                      Coffee Shop  0.04
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.12
# 1                                    Office  0.08
# 2                               Coffee Shop  0.05
# 3                                  Building  0.05
# 4                         Indian Restaurant  0.03
#
#
# ----High Park, The Junction South----
#                  venue  freq
# 0               Church  0.09
# 1  Government Building  0.05
# 2             Building  0.05
# 3               Office  0.05
# 4        Historic Site  0.02
#
#
# ----India Bazaar, The Beaches West----
#                 venue  freq
# 0   Convenience Store  0.07
# 1                Park  0.05
# 2  Salon / Barbershop  0.05
# 3              Church  0.03
# 4  Light Rail Station  0.03
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                     venue  freq
# 0  Thrift / Vintage Store  0.10
# 1      Salon / Barbershop  0.09
# 2                Boutique  0.08
# 3             Art Gallery  0.04
# 4   Vietnamese Restaurant  0.04
#
#
# ----Lawrence Park----
#                   venue  freq
# 0     College Classroom  0.15
# 1                School  0.04
# 2   Housing Development  0.04
# 3              Bus Line  0.04
# 4  Gym / Fitness Center  0.02
#
#
# ----Little Portugal, Trinity----
#                     venue  freq
# 0             Art Gallery  0.12
# 1                     Bar  0.09
# 2                Boutique  0.08
# 3             Coffee Shop  0.05
# 4  Furniture / Home Store  0.03
#
#
# ----Moore Park, Summerhill East----
#                                       venue  freq
# 0                                    Office  0.07
# 1  Residential Building (Apartment / Condo)  0.06
# 2                                      Park  0.05
# 3                                  Building  0.04
# 4                      Other Great Outdoors  0.04
#
#
# ----North Toronto West, Lawrence Park----
#                      venue  freq
# 0           Clothing Store  0.06
# 1               Shoe Store  0.05
# 2           Cosmetics Shop  0.05
# 3  Health & Beauty Service  0.05
# 4   Furniture / Home Store  0.04
#
#
# ----Parkdale, Roncesvalles----
#             venue  freq
# 0     Coffee Shop  0.05
# 1  Breakfast Spot  0.05
# 2             Spa  0.03
# 3     Art Gallery  0.02
# 4  Clothing Store  0.02
#
#
# ----Queen's Park, Ontario Provincial Government----
#                  venue  freq
# 0  Government Building  0.17
# 1       Medical Center  0.07
# 2             Building  0.06
# 3               Office  0.04
# 4     Capitol Building  0.04
#
#
# ----Regent Park, Harbourfront----
#                     venue  freq
# 0         Automotive Shop  0.09
# 1                  Office  0.06
# 2  Furniture / Home Store  0.05
# 3                    Park  0.03
# 4                Building  0.03
#
#
# ----Richmond, Adelaide, King----
#                            venue  freq
# 0                         Office  0.07
# 1                       Building  0.04
# 2                           Café  0.04
# 3                    Coffee Shop  0.04
# 4  Vegetarian / Vegan Restaurant  0.03
#
#
# ----Rosedale----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.16
# 1                                    Office  0.09
# 2                                      Park  0.07
# 3                                      Bank  0.03
# 4                                     Trail  0.03
#
#
# ----Roselawn----
#                                       venue  freq
# 0                                       Spa  0.06
# 1                                    Office  0.06
# 2                                Playground  0.06
# 3                     General Entertainment  0.04
# 4  Residential Building (Apartment / Condo)  0.04
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0      Medical Center  0.06
# 1  Salon / Barbershop  0.05
# 2    Dentist's Office  0.05
# 3    Sushi Restaurant  0.05
# 4      Massage Studio  0.03
#
#
# ----St. James Town----
#                                       venue  freq
# 0                                    Office  0.12
# 1  Residential Building (Apartment / Condo)  0.05
# 2                                  Building  0.05
# 3                               Event Space  0.05
# 4                            Clothing Store  0.02
#
#
# ----St. James Town, Cabbagetown----
#                    venue  freq
# 0                   Café  0.07
# 1            Coffee Shop  0.05
# 2             Street Art  0.05
# 3            Flower Shop  0.04
# 4  General Entertainment  0.03
#
#
# ----Stn A PO Boxes----
#                                       venue  freq
# 0                                    Office  0.22
# 1                                  Building  0.07
# 2  Residential Building (Apartment / Condo)  0.05
# 3                              Tech Startup  0.05
# 4                                       Gym  0.04
#
#
# ----Studio District----
#              venue  freq
# 0      Coffee Shop  0.05
# 1    Moving Target  0.05
# 2  Automotive Shop  0.05
# 3       Restaurant  0.03
# 4         Pharmacy  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.16
# 1                                    Office  0.12
# 2                           Doctor's Office  0.06
# 3                          Dentist's Office  0.05
# 4                                  Building  0.05
#
#
# ----The Annex, North Midtown, Yorkville----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.12
# 1                           Bed & Breakfast  0.05
# 2                                  Building  0.04
# 3                     General Entertainment  0.04
# 4                                Playground  0.02
#
#
# ----The Beaches----
#                     venue  freq
# 0                    Park  0.05
# 1              Playground  0.03
# 2           Jewelry Store  0.03
# 3         Laundry Service  0.03
# 4  Furniture / Home Store  0.02
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.10
# 1                 Spa  0.06
# 2  Salon / Barbershop  0.06
# 3  Miscellaneous Shop  0.04
# 4   Health Food Store  0.03
#
#
# ----Toronto Dominion Centre, Design Exchange----
#          venue  freq
# 0       Office  0.15
# 1  Coffee Shop  0.04
# 2         Park  0.03
# 3         Café  0.03
# 4   Restaurant  0.03
#
#
# ----University of Toronto, Harbord----
#                        venue  freq
# 0     College Residence Hall  0.08
# 1             Student Center  0.07
# 2                 Food Truck  0.06
# 3  College Academic Building  0.04
# 4            College Library  0.04

# %% [markdown]
# <br>
#
# #### Now go through and analyze each neighborhood based on most prevalent types of venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = tor_grouped['Neighborhood']

for ind in np.arange(tor_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(tor_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park                Office
# 1       Brockton, Parkdale Village, Exhibition Place                Office
# 2  Business reply mail Processing Centre, South C...              Building
# 3  CN Tower, King and Spadina, Railway Lands, Har...          Airport Gate
# 4                                 Central Bay Street              Hospital
#
#                       2nd Most Common Venue  \
# 0                                  Building
# 1  Residential Building (Apartment / Condo)
# 2                                    Office
# 3                           Airport Service
# 4                             Hospital Ward
#
#                       3rd Most Common Venue 4th Most Common Venue  \
# 0  Residential Building (Apartment / Condo)               Parking
# 1                              Tech Startup    Advertising Agency
# 2                        Light Rail Station     Convenience Store
# 3                             Moving Target      Airport Terminal
# 4                               Coffee Shop        Medical Center
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Tech Startup            Food Truck           Event Space
# 1                  Café              Building       Coworking Space
# 2        Medical Center               Butcher  Fast Food Restaurant
# 3                  Park        Airport Lounge       Harbor / Marina
# 4              Pharmacy        Emergency Room   Japanese Restaurant
#
#   8th Most Common Venue 9th Most Common Venue    10th Most Common Venue
# 0                 Hotel       Laundry Service                       Pub
# 1                   Bar     Convenience Store               Coffee Shop
# 2               Theater            Restaurant      Gym / Fitness Center
# 3               Airport         Boat or Ferry            General Travel
# 4        Sandwich Place               Parking  Mediterranean Restaurant

# %% [markdown]
# #### Now Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

tor_grouped_clustering = tor_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(tor_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 2, 1, 4, 1, 0, 3, 0, 1, 2], dtype=int32)

# %% [markdown]
# <br>
#
# #### Add labels

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

tor_merged = df_tor

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
tor_merged = tor_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

tor_merged.head() # check the last columns!
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               1       Automotive Shop
# 1  43.662301 -79.389494               3   Government Building
# 2  43.657162 -79.378937               1           College Lab
# 3  43.651494 -79.375418               0                Office
# 4  43.676357 -79.293031               1                  Park
#
#   2nd Most Common Venue                     3rd Most Common Venue  \
# 0                Office                    Furniture / Home Store
# 1        Medical Center                                  Building
# 2            University           College Communications Building
# 3              Building  Residential Building (Apartment / Condo)
# 4         Jewelry Store                                Playground
#
#   4th Most Common Venue         5th Most Common Venue 6th Most Common Venue  \
# 0           Coffee Shop                   Art Gallery    Italian Restaurant
# 1                Office              Capitol Building            Restaurant
# 2           Coffee Shop  General College & University               Parking
# 3           Event Space           Rental Car Location                Church
# 4       Laundry Service                      Bus Stop        Breakfast Spot
#
#    7th Most Common Venue      8th Most Common Venue   9th Most Common Venue  \
# 0        Auto Dealership                   Building                    Park
# 1        Doctor's Office                Medical Lab         College Library
# 2  College Arts Building  College Academic Building   General Entertainment
# 3        Laundry Service                        Spa  Furniture / Home Store
# 4            Coffee Shop               Dance Studio      Miscellaneous Shop
#
#   10th Most Common Venue
# 0          Moving Target
# 1                 Lounge
# 2     Salon / Barbershop
# 3         Clothing Store
# 4            Flower Shop

# %% [markdown]
# <br>
#
# #### Show the clustered neighborhoods on a map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(tor_merged['Latitude'], tor_merged['Longitude'], tor_merged['Neighborhood'], tor_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add column for giving descriptive name to clusters, move that column to the front
new_tor_merged = tor_merged
new_tor_merged['Cluster Name'] = ""
fixed_columns = [new_tor_merged.columns[-1]] + list(new_tor_merged.columns[:-1])
new_tor_merged = new_tor_merged[fixed_columns]
# Out:
#   Cluster Name Postal Code           Borough  \
# 0                      M5A  Downtown Toronto
# 1                      M7A  Downtown Toronto
# 2                      M5B  Downtown Toronto
# 3                      M5C  Downtown Toronto
# 4                      M4E      East Toronto
#
#                                   Neighborhood   Latitude  Longitude  \
# 0                    Regent Park, Harbourfront  43.654260 -79.360636
# 1  Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                     Garden District, Ryerson  43.657162 -79.378937
# 3                               St. James Town  43.651494 -79.375418
# 4                                  The Beaches  43.676357 -79.293031
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1       Automotive Shop                Office
# 1               3   Government Building        Medical Center
# 2               1           College Lab            University
# 3               0                Office              Building
# 4               1                  Park         Jewelry Store
#
#                       3rd Most Common Venue 4th Most Common Venue  \
# 0                    Furniture / Home Store           Coffee Shop
# 1                                  Building                Office
# 2           College Communications Building           Coffee Shop
# 3  Residential Building (Apartment / Condo)           Event Space
# 4                                Playground       Laundry Service
#
#           5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 0                   Art Gallery    Italian Restaurant        Auto Dealership
# 1              Capitol Building            Restaurant        Doctor's Office
# 2  General College & University               Parking  College Arts Building
# 3           Rental Car Location                Church        Laundry Service
# 4                      Bus Stop        Breakfast Spot            Coffee Shop
#
#        8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 0                   Building                    Park          Moving Target
# 1                Medical Lab         College Library                 Lounge
# 2  College Academic Building   General Entertainment     Salon / Barbershop
# 3                        Spa  Furniture / Home Store         Clothing Store
# 4               Dance Studio      Miscellaneous Shop            Flower Shop

# %% [markdown]
# <br>
#
# ## Now, look through the clusters and give each one an appropriate descriptive name

# %% [markdown]
# #### Cluster 0

# %%
# Check out the first category
display(new_tor_merged.loc[new_tor_merged['Cluster Labels'] == 0, new_tor_merged.columns[[2] + [3] + [0] + list(range(6, new_tor_merged.shape[1]))]])
# Give it an appropriate name
Labels = {0: "Commercial District"}
# Out:
#              Borough                              Neighborhood Cluster Name  \
# 3   Downtown Toronto                            St. James Town
# 7   Downtown Toronto                                  Christie
# 8   Downtown Toronto                  Richmond, Adelaide, King
# 13  Downtown Toronto  Toronto Dominion Centre, Design Exchange
# 16  Downtown Toronto            Commerce Court, Victoria Hotel
# 34  Downtown Toronto                            Stn A PO Boxes
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3                0                Office              Building
# 7                0                Office                  Café
# 8                0                Office              Building
# 13               0                Office           Coffee Shop
# 16               0                Office           Coffee Shop
# 34               0                Office              Building
#
#                        3rd Most Common Venue  \
# 3   Residential Building (Apartment / Condo)
# 7                     Furniture / Home Store
# 8                                       Café
# 13                                Restaurant
# 16                Financial or Legal Service
# 34                              Tech Startup
#
#                        4th Most Common Venue 5th Most Common Venue  \
# 3                                Event Space   Rental Car Location
# 7                                     Bakery         Design Studio
# 8                                Coffee Shop            Food Court
# 13                                      Park                  Café
# 16                                      Bank    Salon / Barbershop
# 34  Residential Building (Apartment / Condo)                   Pub
#
#             6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 3                          Church       Laundry Service                   Spa
# 7                   Grocery Store       Laundry Service  Gym / Fitness Center
# 8   Vegetarian / Vegan Restaurant                  Pool     Indian Restaurant
# 13                       Building       Coworking Space           Event Space
# 16                     Food Court      Video Game Store            Restaurant
# 34                          Hotel                   Gym                   Bar
#
#        9th Most Common Venue 10th Most Common Venue
# 3     Furniture / Home Store         Clothing Store
# 7            Automotive Shop              Nightclub
# 8   Bike Rental / Bike Share               Ballroom
# 13             Deli / Bodega     Italian Restaurant
# 16                  Building          Deli / Bodega
# 34           Laundry Service     Italian Restaurant

# %% [markdown]
# #### Cluster 1

# %%
# Check out the next category
display(new_tor_merged.loc[new_tor_merged['Cluster Labels'] == 1, new_tor_merged.columns[[2] + [3] + [0] + list(range(6, new_tor_merged.shape[1]))]])
# Give it an appropriate name
Labels[1] = "Culture District"
# Out:
#              Borough                                       Neighborhood  \
# 0   Downtown Toronto                          Regent Park, Harbourfront
# 2   Downtown Toronto                           Garden District, Ryerson
# 4       East Toronto                                        The Beaches
# 6   Downtown Toronto                                 Central Bay Street
# 9       West Toronto                       Dufferin, Dovercourt Village
# 11      West Toronto                           Little Portugal, Trinity
# 12      East Toronto                       The Danforth West, Riverdale
# 15      East Toronto                     India Bazaar, The Beaches West
# 17      East Toronto                                    Studio District
# 18   Central Toronto                                      Lawrence Park
# 23   Central Toronto                  North Toronto West, Lawrence Park
# 25      West Toronto                             Parkdale, Roncesvalles
# 26   Central Toronto                                         Davisville
# 27  Downtown Toronto                     University of Toronto, Harbord
# 28      West Toronto                                 Runnymede, Swansea
# 30  Downtown Toronto          Kensington Market, Chinatown, Grange Park
# 35  Downtown Toronto                        St. James Town, Cabbagetown
# 36  Downtown Toronto             First Canadian Place, Underground city
# 38      East Toronto  Business reply mail Processing Centre, South C...
#
#         Cluster Name  Cluster Labels   1st Most Common Venue  \
# 0   Culture District               1         Automotive Shop
# 2   Culture District               1             College Lab
# 4   Culture District               1                    Park
# 6   Culture District               1                Hospital
# 9   Culture District               1         Automotive Shop
# 11  Culture District               1             Art Gallery
# 12  Culture District               1        Greek Restaurant
# 15  Culture District               1       Convenience Store
# 17  Culture District               1         Automotive Shop
# 18  Culture District               1       College Classroom
# 23  Culture District               1          Clothing Store
# 25  Culture District               1             Coffee Shop
# 26  Culture District               1             Coffee Shop
# 27  Culture District               1  College Residence Hall
# 28  Culture District               1          Medical Center
# 30  Culture District               1  Thrift / Vintage Store
# 35  Culture District               1                    Café
# 36  Culture District               1                  Bakery
# 38  Culture District               1                Building
#
#    2nd Most Common Venue            3rd Most Common Venue  \
# 0                 Office           Furniture / Home Store
# 2             University  College Communications Building
# 4          Jewelry Store                       Playground
# 6          Hospital Ward                      Coffee Shop
# 9                   Park                           Church
# 11                   Bar                         Boutique
# 12                   Spa               Salon / Barbershop
# 15    Salon / Barbershop                             Park
# 17           Coffee Shop                    Moving Target
# 18   Housing Development                         Bus Line
# 23            Shoe Store          Health & Beauty Service
# 25        Breakfast Spot                              Spa
# 26                  Café               Italian Restaurant
# 27        Student Center                       Food Truck
# 28    Salon / Barbershop                 Sushi Restaurant
# 30    Salon / Barbershop                         Boutique
# 35            Street Art                      Coffee Shop
# 36           Coffee Shop               Salon / Barbershop
# 38                Office               Light Rail Station
#
#      4th Most Common Venue         5th Most Common Venue  \
# 0              Coffee Shop                   Art Gallery
# 2              Coffee Shop  General College & University
# 4          Laundry Service                      Bus Stop
# 6           Medical Center                      Pharmacy
# 9   Furniture / Home Store                        Office
# 11             Coffee Shop        Furniture / Home Store
# 12      Miscellaneous Shop             Health Food Store
# 15      Light Rail Station                        Church
# 17                Pharmacy                    Restaurant
# 18                  School                          Park
# 23          Cosmetics Shop        Furniture / Home Store
# 25               Gift Shop                     Bookstore
# 26      Salon / Barbershop                   Flower Shop
# 27         College Library     College Academic Building
# 28        Dentist's Office                Massage Studio
# 30                     Bar                   Art Gallery
# 35             Flower Shop                   Pizza Place
# 36                  Office                Clothing Store
# 38       Convenience Store                Medical Center
#
#     6th Most Common Venue   7th Most Common Venue      8th Most Common Venue  \
# 0      Italian Restaurant         Auto Dealership                   Building
# 2                 Parking   College Arts Building  College Academic Building
# 4          Breakfast Spot             Coffee Shop               Dance Studio
# 6          Emergency Room     Japanese Restaurant             Sandwich Place
# 9   Portuguese Restaurant                 Factory                  Speakeasy
# 11            Pizza Place                  Office             Clothing Store
# 12          Women's Store    Gym / Fitness Center             Pilates Studio
# 15        Laundry Service               Pet Store                Art Gallery
# 17             Nail Salon        Dentist's Office                        Spa
# 18                   Pool      Salon / Barbershop                   Building
# 23            Men's Store        Toy / Game Store                Coffee Shop
# 25    Indie Movie Theater                Boutique                       Bank
# 26            Candy Store               Bookstore            Laundry Service
# 27      College Classroom             College Gym                College Lab
# 28            Pizza Place  Furniture / Home Store                       Café
# 30  Vietnamese Restaurant      Chinese Restaurant             Farmers Market
# 35               Pharmacy              Restaurant      General Entertainment
# 36         Cosmetics Shop      Chinese Restaurant                 Restaurant
# 38                Butcher    Fast Food Restaurant                    Theater
#
#     9th Most Common Venue    10th Most Common Venue
# 0                    Park             Moving Target
# 2   General Entertainment        Salon / Barbershop
# 4      Miscellaneous Shop               Flower Shop
# 6                 Parking  Mediterranean Restaurant
# 9           Jewelry Store             Grocery Store
# 11           Cocktail Bar        Salon / Barbershop
# 12         Ice Cream Shop            Shop & Service
# 15             Board Shop      Fast Food Restaurant
# 17               Building        Seafood Restaurant
# 18                   Bank                    Church
# 23  General Entertainment             Metro Station
# 25               Building               Event Space
# 26                Library    Thrift / Vintage Store
# 27            Coffee Shop                University
# 28                 Bakery  Mediterranean Restaurant
# 30         Clothing Store             Grocery Store
# 35              Pet Store                       Spa
# 36           Camera Store               Salad Place
# 38             Restaurant      Gym / Fitness Center

# %% [markdown]
# #### Cluster 2

# %%
# Check out the next category
display(new_tor_merged.loc[new_tor_merged['Cluster Labels'] == 2, new_tor_merged.columns[[2] + [3] + [0] + list(range(6, new_tor_merged.shape[1]))]])
# Give it an appropriate name
Labels[2] = "Apartments District"
# Out:
#              Borough                                       Neighborhood  \
# 10  Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 14      West Toronto       Brockton, Parkdale Village, Exhibition Place
# 20   Central Toronto                                   Davisville North
# 31   Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 33  Downtown Toronto                                           Rosedale
#
#            Cluster Name  Cluster Labels  \
# 10  Apartments District               2
# 14  Apartments District               2
# 20  Apartments District               2
# 31  Apartments District               2
# 33  Apartments District               2
#
#                        1st Most Common Venue  \
# 10  Residential Building (Apartment / Condo)
# 14                                    Office
# 20  Residential Building (Apartment / Condo)
# 31  Residential Building (Apartment / Condo)
# 33  Residential Building (Apartment / Condo)
#
#                        2nd Most Common Venue 3rd Most Common Venue  \
# 10                                    Office           Coffee Shop
# 14  Residential Building (Apartment / Condo)          Tech Startup
# 20                                    Office               Dog Run
# 31                                    Office       Doctor's Office
# 33                                    Office                  Park
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 10              Building       Doctor's Office   Fried Chicken Joint
# 14    Advertising Agency                  Café              Building
# 20                   Gym        Scenic Lookout            Playground
# 31              Building      Dentist's Office        Medical Center
# 33  Other Great Outdoors                 Trail                  Bank
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 10               Parking    Light Rail Station     Indian Restaurant
# 14       Coworking Space                   Bar     Convenience Store
# 20                  Park            Strip Club        Breakfast Spot
# 31    Light Rail Station                  Café      Spiritual Center
# 33   Government Building    Salon / Barbershop                Bridge
#
#    10th Most Common Venue
# 10           Tech Startup
# 14            Coffee Shop
# 20               Building
# 31                  Diner
# 33                Dog Run

# %% [markdown]
# #### Cluster 3

# %%
# Check out the next category
display(new_tor_merged.loc[new_tor_merged['Cluster Labels'] == 3, new_tor_merged.columns[[2] + [3] + [0] + list(range(6, new_tor_merged.shape[1]))]])
# Give it an appropriate name
Labels[3] = "Municipal District"
# Out:
#              Borough                                     Neighborhood  \
# 1   Downtown Toronto      Queen's Park, Ontario Provincial Government
# 5   Downtown Toronto                                      Berczy Park
# 19   Central Toronto                                         Roselawn
# 21   Central Toronto  Forest Hill North & West, Forest Hill Road Park
# 22      West Toronto                    High Park, The Junction South
# 24   Central Toronto              The Annex, North Midtown, Yorkville
# 29   Central Toronto                      Moore Park, Summerhill East
# 37  Downtown Toronto                             Church and Wellesley
#
#    Cluster Name  Cluster Labels                     1st Most Common Venue  \
# 1                             3                       Government Building
# 5                             3                                    Office
# 19                            3                                    Office
# 21                            3  Residential Building (Apartment / Condo)
# 22                            3                                    Church
# 24                            3  Residential Building (Apartment / Condo)
# 29                            3                                    Office
# 37                            3  Residential Building (Apartment / Condo)
#
#                        2nd Most Common Venue  \
# 1                             Medical Center
# 5                                   Building
# 19                                       Spa
# 21                                    Office
# 22                                    Office
# 24                           Bed & Breakfast
# 29  Residential Building (Apartment / Condo)
# 37                                       Spa
#
#                        3rd Most Common Venue  4th Most Common Venue  \
# 1                                   Building                 Office
# 5   Residential Building (Apartment / Condo)                Parking
# 19                                Playground        Doctor's Office
# 21                                      Park   Gym / Fitness Center
# 22                       Government Building               Building
# 24                                  Building  General Entertainment
# 29                                      Park   Other Great Outdoors
# 37                     General Entertainment                 Office
#
#                        5th Most Common Venue  6th Most Common Venue  \
# 1                           Capitol Building             Restaurant
# 5                               Tech Startup             Food Truck
# 19  Residential Building (Apartment / Condo)                    Gym
# 21                              Tech Startup  General Entertainment
# 22                        Salon / Barbershop                Parking
# 24                             Metro Station                 Garden
# 29                                  Building                  Trail
# 37                                       Gym   Gym / Fitness Center
#
#     7th Most Common Venue 8th Most Common Venue  \
# 1         Doctor's Office           Medical Lab
# 5             Event Space                 Hotel
# 19  General Entertainment             Synagogue
# 21        Doctor's Office           Gas Station
# 22            Post Office     College Classroom
# 24                   Café    Miscellaneous Shop
# 29                 Bridge            Playground
# 37               Building                  Bank
#
#                        9th Most Common Venue 10th Most Common Venue
# 1                            College Library                 Lounge
# 5                            Laundry Service                    Pub
# 19                             Moving Target     Italian Restaurant
# 21                          Asian Restaurant                 Lawyer
# 22  Residential Building (Apartment / Condo)           Chiropractor
# 24                                       Spa              Speakeasy
# 29                         Martial Arts Dojo                    Gym
# 37                                     Hotel                    Pub

# %% [markdown]
# #### Cluster 4

# %%
# Check out the next category
display(new_tor_merged.loc[new_tor_merged['Cluster Labels'] == 4, new_tor_merged.columns[[2] + [3] + [0] + list(range(6, new_tor_merged.shape[1]))]])
# Give it an appropriate name
Labels[4] = "Airport"
# Out:
#              Borough                                       Neighborhood  \
# 32  Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
#
#    Cluster Name  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 32                            4          Airport Gate       Airport Service
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 32         Moving Target      Airport Terminal                  Park
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 32        Airport Lounge       Harbor / Marina               Airport
#
#    9th Most Common Venue 10th Most Common Venue
# 32         Boat or Ferry         General Travel

# %% [markdown]
# ## Now put the labels in the dataframe, show some group statistics, and we are done!

# %%
new_tor_merged['Cluster Name'] = new_tor_merged['Cluster Labels'].map(Labels)
grouped = new_tor_merged.groupby(['Cluster Labels', 'Cluster Name']).size().reset_index(name='Number of Areas')
grouped.set_index('Cluster Labels', inplace=True)
grouped.sort_values('Cluster Labels')
# Out:
#                        Cluster Name  Number of Areas
# Cluster Labels
# 0               Commercial District                6
# 1                  Culture District               19
# 2               Apartments District                5
# 3                Municipal District                8
# 4                           Airport                1
